# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("debug_preprocess.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img = cv2.imread("debug_threshold.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img = cv2.imread("debug_segmentation.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img = cv2.imread("debug_quads_raw.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img = cv2.imread("debug_quads_fixed.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img = cv2.imread("debug_samples.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()

# %%
img = cv2.imread("debug_output.pnm", cv2.IMREAD_UNCHANGED)

plt.imshow(img, cmap='gray')
plt.axis("off")
plt.show()
